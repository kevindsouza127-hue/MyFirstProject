-- %% [markdown]
-- # [Labcare_New]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Labcare_New]    Script Date: 07/03/2025 8:53:22 PM ******/
CREATE DATABASE [Labcare_New]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Labcare_New', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.KEVIN\MSSQL\DATA\Labcare_New.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Labcare_New_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.KEVIN\MSSQL\DATA\Labcare_New_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [Labcare_New] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Labcare_New].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Labcare_New] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Labcare_New] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Labcare_New] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Labcare_New] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Labcare_New] SET ARITHABORT OFF 
GO
ALTER DATABASE [Labcare_New] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Labcare_New] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Labcare_New] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Labcare_New] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Labcare_New] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Labcare_New] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Labcare_New] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Labcare_New] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Labcare_New] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Labcare_New] SET  ENABLE_BROKER 
GO
ALTER DATABASE [Labcare_New] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Labcare_New] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Labcare_New] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Labcare_New] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Labcare_New] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Labcare_New] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Labcare_New] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Labcare_New] SET RECOVERY FULL 
GO
ALTER DATABASE [Labcare_New] SET  MULTI_USER 
GO
ALTER DATABASE [Labcare_New] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Labcare_New] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Labcare_New] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Labcare_New] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Labcare_New] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Labcare_New] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'Labcare_New', N'ON'
GO
ALTER DATABASE [Labcare_New] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[AuditLog]

-- %%
USE [Labcare_New]
GO

-- %%
/****** Object:  Table [dbo].[AuditLog]    Script Date: 07/03/2025 8:53:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AuditLog](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[ActionType] [varchar](250) NULL,
	[CentreCode] [varchar](250) NULL,
	[UserID] [varchar](250) NULL,
	[Value] [varchar](200) NULL,
	[PreviousValue] [varchar](200) NULL,
	[NewValue] [varchar](200) NULL,
	[UpdatedDateTime] [datetime] NULL,
	[ALcompname] [varchar](250) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Category]

-- %%
/****** Object:  Table [dbo].[Category]    Script Date: 07/03/2025 8:53:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Category](
	[Category] [varchar](50) NOT NULL,
	[CatShortCut] [varchar](10) NULL,
	[MainCat] [varchar](50) NULL,
	[LastNo] [int] NULL,
	[DocCode] [real] NULL,
	[barcodecopy] [int] NULL,
	[CatCode] [int] NULL,
	[doccode1] [varchar](50) NULL,
	[doctorlicenceno] [varchar](250) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Doctor]

-- %%
/****** Object:  Table [dbo].[Doctor]    Script Date: 07/03/2025 8:53:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Doctor](
	[DocCode] [int] NOT NULL,
	[DocName] [varchar](100) NOT NULL,
	[DocSpeciality] [varchar](100) NULL,
	[DocPhone] [varchar](20) NULL,
	[DocAddress] [varchar](255) NULL,
	[Phone2] [varchar](20) NULL,
	[DocStatus] [varchar](1) NULL,
	[DocId] [real] NULL,
	[DocArea] [varchar](20) NULL,
	[DocCenAlias] [varchar](1) NULL,
	[Timing] [varchar](255) NULL,
	[EMail] [varchar](255) NULL,
	[Mobile] [varchar](20) NULL,
	[ZipCode] [varchar](10) NULL,
	[MailType] [varchar](10) NULL,
	[DocPassword] [varchar](10) NULL,
	[DocL] [varchar](10) NULL,
	[hmscode] [varchar](20) NULL,
	[processAt] [int] NULL,
	[docmname] [varchar](50) NULL,
	[doclname] [varchar](50) NULL,
	[licence] [varchar](50) NULL,
	[drcencode] [varchar](50) NULL,
	[docrefferal] [int] NULL,
	[doc_cencode] [int] NULL,
	[mobiletest] [varchar](250) NULL,
	[mobiletest1] [varchar](100) NULL,
	[doctorreftype] [varchar](10) NULL,
	[doc_cenname] [varchar](250) NULL,
	[docemailcc] [varchar](1000) NULL,
	[DocWebLogin] [varchar](250) NULL,
	[DocWebpass] [varchar](250) NULL,
	[uploadonweb] [varchar](1) NULL,
 CONSTRAINT [PK_Doctor] PRIMARY KEY CLUSTERED 
(
	[DocCode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, FILLFACTOR = 90, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[JwtToken]

-- %%
/****** Object:  Table [dbo].[JwtToken]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[JwtToken](
	[Id] [int] IDENTITY(100,1) NOT NULL,
	[Userid] [nvarchar](250) NULL,
	[JwtTokenId] [varchar](500) NOT NULL,
	[TokenExpires] [datetime] NOT NULL,
	[TokenIsExpired] [datetime] NULL,
	[TokenCreated] [datetime] NULL,
 CONSTRAINT [pk_Jwtid] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MainCategory]

-- %%
/****** Object:  Table [dbo].[MainCategory]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MainCategory](
	[Main] [varchar](50) NOT NULL,
	[LastNo] [int] NULL,
	[MainReset] [varchar](50) NULL,
	[CutMode] [varchar](1) NULL,
	[LabNoPerTest] [bit] NOT NULL,
	[MainCatCode] [int] NULL,
	[CurrDate] [datetime] NULL,
	[CenConnStr] [varchar](50) NULL,
	[ieflag] [varchar](1) NULL,
 CONSTRAINT [PK_MainCategory] PRIMARY KEY CLUSTERED 
(
	[Main] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, FILLFACTOR = 90, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OSLABMASTER]

-- %%
/****** Object:  Table [dbo].[OSLABMASTER]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OSLABMASTER](
	[OSLabCode] [int] IDENTITY(1,1) NOT NULL,
	[OSLabName] [nvarchar](100) NULL,
	[OSContactPerson] [nvarchar](50) NULL,
	[OSAddress] [nvarchar](255) NULL,
	[OSPhone1] [nvarchar](30) NULL,
	[OSPhone2] [nvarchar](30) NULL,
	[OSFax] [nvarchar](20) NULL,
	[OSEmailID] [nvarchar](30) NULL,
	[Valid] [nvarchar](1) NULL,
	[IsReffered] [nvarchar](1) NULL,
 CONSTRAINT [PK_OSLABMASTER] PRIMARY KEY CLUSTERED 
(
	[OSLabCode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, FILLFACTOR = 90, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Param]

-- %%
/****** Object:  Table [dbo].[Param]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Param](
	[ParamCode] [int] IDENTITY(1,1) NOT NULL,
	[ParamName] [nvarchar](100) NULL,
	[ParamPrintHead] [nvarchar](100) NULL,
	[ParamUnit] [nvarchar](150) NULL,
	[ParamMethod] [nvarchar](100) NULL,
	[ParamRate] [money] NULL,
	[ParamMaleNormal] [nvarchar](255) NULL,
	[ParamFemaleNormal] [nvarchar](255) NULL,
	[ParamChild1Normal] [nvarchar](255) NULL,
	[ParamChild6Normal] [nvarchar](255) NULL,
	[ParamChildNormal] [nvarchar](255) NULL,
	[ParamMaleDef] [nvarchar](255) NULL,
	[ParamFemaleDef] [nvarchar](255) NULL,
	[ParamChild1Def] [nvarchar](255) NULL,
	[ParamChild6Def] [nvarchar](255) NULL,
	[ParamChildDef] [nvarchar](255) NULL,
	[ParamMaleHigh] [real] NULL,
	[ParamFemaleHigh] [real] NULL,
	[ParamChild1High] [real] NULL,
	[ParamChild6High] [real] NULL,
	[ParamChildHigh] [real] NULL,
	[ParamMaleLow] [real] NULL,
	[ParamFemaleLow] [real] NULL,
	[ParamChild1Low] [real] NULL,
	[ParamChild6Low] [real] NULL,
	[ParamChildLow] [real] NULL,
	[ParamValidFlag] [nvarchar](50) NULL,
	[ParamDef2] [ntext] NULL,
	[ParamFooter] [ntext] NULL,
	[SampleType] [real] NULL,
	[Suffix] [nvarchar](50) NULL,
	[pPrecision] [smallint] NULL,
	[SENDSMS] [nvarchar](1) NULL,
	[Formula] [nvarchar](250) NULL,
	[DC] [nvarchar](1) NULL,
	[ParamType] [nvarchar](1) NULL,
	[nabl] [char](10) NULL,
	[observation] [nvarchar](50) NULL,
	[observationcode] [nvarchar](50) NULL,
	[observationresult] [real] NULL,
	[SIFACTOR] [nvarchar](50) NULL,
	[SIUNIT] [nvarchar](50) NULL,
	[paramhmscode] [nvarchar](50) NULL,
	[accrediation] [nvarchar](50) NULL,
	[hmsocode] [nvarchar](250) NULL,
	[hmscode] [nvarchar](250) NULL,
	[parammethod1] [nvarchar](250) NULL,
	[OBSERVATIONCPT] [nvarchar](100) NULL,
	[observationunit] [nvarchar](250) NULL,
	[pprecisionsi] [smallint] NULL,
	[paramdeltatype] [nvarchar](1) NULL,
	[paramdeltarange] [int] NULL,
	[ForNonReport] [bit] NULL,
	[isMandatory] [bit] NULL,
	[Usehelpvalue] [bit] NULL,
	[reportingunit] [nvarchar](10) NULL,
	[doneby] [nvarchar](250) NULL,
	[adactivity] [nvarchar](250) NULL,
	[compname] [nvarchar](250) NULL,
	[activitydttime] [datetime] NULL,
 CONSTRAINT [PK_Param] PRIMARY KEY CLUSTERED 
(
	[ParamCode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, FILLFACTOR = 90, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParamHelpValues]

-- %%
/****** Object:  Table [dbo].[ParamHelpValues]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParamHelpValues](
	[ParamCode] [smallint] NULL,
	[ParamHelpValue] [ntext] NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParamNormalRange]

-- %%
/****** Object:  Table [dbo].[ParamNormalRange]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParamNormalRange](
	[ParamCode] [int] NOT NULL,
	[GreaterThanDays] [int] NOT NULL,
	[LessThanDays] [int] NOT NULL,
	[Sex] [varchar](1) NOT NULL,
	[ParamSINormal] [nvarchar](255) NULL,
	[ParamSIHigh] [real] NULL,
	[ParamSILow] [real] NULL,
	[ParamConvNormal] [nvarchar](500) NULL,
	[ParamConvHigh] [real] NULL,
	[ParamConvLow] [real] NULL,
	[ParamCriNormal] [nvarchar](255) NULL,
	[ParamCriHigh] [real] NULL,
	[ParamCriLow] [real] NULL,
	[ParamDefault] [nvarchar](255) NULL,
	[paramauthtext] [nvarchar](250) NULL,
	[CentresSysNo] [int] NULL,
	[doneby] [nvarchar](250) NULL,
	[adactivity] [nvarchar](250) NULL,
	[compname] [nvarchar](250) NULL,
	[activitydttime] [datetime] NULL,
	[ParamAuthLow] [real] NULL,
	[ParamAuthHigh] [real] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Patient]

-- %%
/****** Object:  Table [dbo].[Patient]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Patient](
	[PatCode] [real] NOT NULL,
	[PatName] [varchar](100) NULL,
	[PatAddress] [varchar](255) NULL,
	[PatSex] [varchar](1) NULL,
	[PatType] [varchar](1) NULL,
	[PatPhone] [varchar](100) NULL,
	[PatDocCode] [real] NULL,
	[DOB] [datetime] NULL,
	[PatStatus] [varchar](1) NULL,
	[PermNo] [varchar](50) NULL,
	[PatTitle] [varchar](100) NULL,
	[EMail] [varchar](255) NULL,
	[Mobile] [varchar](20) NULL,
	[faxno] [varchar](20) NULL,
	[bedno] [varchar](20) NULL,
	[ipop] [varchar](1) NULL,
	[patage] [int] NULL,
	[patageunit] [varchar](20) NULL,
	[GroupCode] [varchar](10) NULL,
	[NationalityCode] [varchar](10) NULL,
	[passport] [varchar](50) NULL,
	[ID] [varchar](50) NULL,
	[socsecno] [varchar](50) NULL,
	[patmname] [varchar](50) NULL,
	[patlname] [varchar](50) NULL,
	[patfname] [varchar](250) NULL,
	[Validtill] [datetime] NULL,
	[BusinessPhNo] [varchar](100) NULL,
	[MaritalStatus] [varchar](20) NULL,
	[PrimaryLang] [varchar](100) NULL,
	[Religion] [varchar](100) NULL,
	[SSNNo] [varchar](100) NULL,
	[RegCencode] [int] NULL,
	[Hasana_ID] [varchar](50) NULL,
	[MOHAP_ID] [int] NULL,
	[HusbandName] [varchar](250) NULL,
	[HusbandDOB] [datetime] NULL,
	[HusbandGender] [varchar](1) NULL,
	[UniqueID] [varchar](50) NULL,
	[inserteddate] [datetime] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Reason]

-- %%
/****** Object:  Table [dbo].[Reason]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Reason](
	[Reason] [nvarchar](255) NULL,
	[ReasonFlag] [nvarchar](2) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Result]

-- %%
/****** Object:  Table [dbo].[Result]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Result](
	[TrJobCode] [varchar](20) NOT NULL,
	[TrTestCode] [smallint] NOT NULL,
	[TrParamCode] [smallint] NOT NULL,
	[TrResult] [varchar](255) NULL,
	[TrThPrintOrder] [tinyint] NULL,
	[TrThpPrintOrder] [tinyint] NULL,
	[LabNo] [int] NULL,
	[MachineId] [varchar](50) NULL,
	[ParamNormal] [varchar](500) NULL,
	[ParamHigh] [real] NULL,
	[ParamLow] [real] NULL,
	[AbnormalFlag] [varchar](1) NULL,
	[TestParamBlank] [int] NULL,
	[ParamType] [varchar](1) NULL,
	[Formula] [varchar](250) NULL,
	[DC] [varchar](1) NULL,
	[SENDSMS] [varchar](1) NULL,
	[status] [varchar](1) NULL,
	[remark] [varchar](1) NULL,
	[trparamfooter] [text] NULL,
	[crilow] [real] NULL,
	[crihigh] [real] NULL,
	[crinormal] [varchar](255) NULL,
	[criflag] [varchar](1) NULL,
	[trautocomment] [varchar](250) NULL,
	[criauthtext] [varchar](250) NULL,
	[silow] [real] NULL,
	[siresult] [varchar](250) NULL,
	[sihigh] [real] NULL,
	[sinormal] [varchar](1000) NULL,
	[UID] [varchar](100) NULL,
	[UDATETIME] [datetime] NULL,
	[resulttime] [datetime] NULL,
	[QryTime] [datetime] NULL,
	[trunit] [varchar](100) NULL,
	[refrangemodifyby] [varchar](250) NULL,
	[refrangemodifydate] [datetime] NULL,
	[c6ktestsent] [varchar](1) NULL,
	[c6kAtestsent] [varchar](1) NULL,
	[TRDELTAFAILED] [varchar](1) NULL,
	[trparamunit] [varchar](100) NULL,
	[RegCenCode] [int] NULL,
	[ProcessCenCode] [int] NULL,
	[trmethod] [varchar](250) NULL,
	[autoauthlow] [real] NULL,
	[autoauthhigh] [real] NULL,
	[autoauthflag] [varchar](1) NULL,
	[trautoauthflag] [varchar](1) NULL,
	[inserteddate] [datetime] NULL,
	[trparamauthtext] [varchar](250) NULL,
 CONSTRAINT [PK_Result] PRIMARY KEY CLUSTERED 
(
	[TrJobCode] ASC,
	[TrTestCode] ASC,
	[TrParamCode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, FILLFACTOR = 90, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Result2]

-- %%
/****** Object:  Table [dbo].[Result2]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Result2](
	[Tr2JobCode] [varchar](20) NOT NULL,
	[Tr2TestCode] [smallint] NOT NULL,
	[Tr2ParamCode] [smallint] NOT NULL,
	[Tr2Result] [ntext] NULL,
	[Tr2ThPrintOrder] [tinyint] NULL,
	[Tr2ThpPrintOrder] [tinyint] NULL,
	[LabNo] [int] NULL,
	[flag] [varchar](1) NULL,
	[pageno] [int] NULL,
	[tr2rlen] [varchar](50) NULL,
	[tr2ole] [varchar](50) NULL,
	[RegCenCode] [int] NULL,
	[ProcessCenCode] [int] NULL,
	[inserteddate] [datetime] NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ResultTest]

-- %%
/****** Object:  Table [dbo].[ResultTest]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ResultTest](
	[RtJobCode] [varchar](20) NOT NULL,
	[RtProfCode] [smallint] NOT NULL,
	[RtTestCode] [smallint] NOT NULL,
	[RtJobOver] [bit] NULL,
	[RtPageNumber] [smallint] NULL,
	[RtPageSize] [smallint] NULL,
	[RtTestPrinted] [varchar](1) NULL,
	[RtCenCode] [int] NULL,
	[RtDoctor] [varchar](100) NULL,
	[RtCaseNo] [varchar](50) NULL,
	[RtRegion] [varchar](50) NULL,
	[RtAuth] [bit] NULL,
	[LabNo] [int] NULL,
	[RtDispatchDate] [datetime] NULL,
	[RtInvalidUserId] [varchar](20) NULL,
	[RtInvalidReason] [varchar](50) NULL,
	[RtRecNo] [varchar](100) NULL,
	[RtDispatchMode] [varchar](10) NULL,
	[RtInvalidDate] [datetime] NULL,
	[RtCat] [varchar](50) NULL,
	[RtWeb] [varchar](1) NULL,
	[SampleDate] [datetime] NULL,
	[SampleTime] [varchar](50) NULL,
	[BillNo] [varchar](20) NULL,
	[RtRate] [money] NULL,
	[samplestatus] [varchar](1) NULL,
	[status] [varchar](1) NULL,
	[SENDSMS] [varchar](1) NULL,
	[billid] [int] NULL,
	[accheadcode] [char](3) NULL,
	[SMSDeliver] [varchar](1) NULL,
	[SMSUID] [varchar](50) NULL,
	[SMSDateTime] [datetime] NULL,
	[ProcessingCenCode] [int] NULL,
	[RTPendingReason] [varchar](50) NULL,
	[dispatcheddt] [datetime] NULL,
	[DispatchUID] [varchar](50) NULL,
	[DispatchDeliverUID] [varchar](50) NULL,
	[stat] [int] NULL,
	[refferal] [money] NULL,
	[OSTransctionID] [varchar](50) NULL,
	[oslabassign] [varchar](50) NULL,
	[RtTestCount] [int] NULL,
	[histopathno] [varchar](50) NULL,
	[specimen] [text] NULL,
	[schdispatchdt] [varchar](50) NULL,
	[receiveddate] [datetime] NULL,
	[histopathdigcode] [varchar](50) NULL,
	[showrec] [int] NULL,
	[showspec] [int] NULL,
	[SENDFAX] [varchar](1) NULL,
	[ORGSEEN] [varchar](1) NULL,
	[ORGGROWTH] [varchar](1) NULL,
	[DOSTAIN] [varchar](1) NULL,
	[specimencode] [varchar](10) NULL,
	[resubmissiontype] [varchar](50) NULL,
	[resubmissioncomment] [varchar](50) NULL,
	[affectedrtrate] [money] NULL,
	[PROCESSED] [varchar](1) NULL,
	[rtintest] [int] NULL,
	[sendfax1] [varchar](1) NULL,
	[calcrtrate] [money] NULL,
	[rthmscode] [varchar](250) NULL,
	[rtcalchmscode] [varchar](250) NULL,
	[rtpatientshare] [money] NULL,
	[eclaimcomment] [varchar](250) NULL,
	[rttestfooter] [varchar](5000) NULL,
	[microesbl] [varchar](1) NULL,
	[Inssamplestatus] [varchar](1) NULL,
	[rtinspaid] [money] NULL,
	[rtpaymentrefno] [varchar](250) NULL,
	[rtstartdate] [datetime] NULL,
	[rtenddate] [datetime] NULL,
	[rtvat] [money] NULL,
	[rtvatperc] [int] NULL,
	[rtvatcategory] [int] NULL,
	[rtinsfactor] [float] NULL,
	[SpecimenAdditive] [varchar](100) NULL,
	[SpecimenCondition] [varchar](100) NULL,
	[SpecimenQuality] [varchar](100) NULL,
	[RegCenCode] [int] NULL,
	[histocptcomment] [varchar](250) NULL,
	[histoslidepreparedby] [varchar](250) NULL,
	[histoslidestainedby] [varchar](250) NULL,
	[rtsendprocesslab] [int] NULL,
	[rtsendprocesslabdatetime] [datetime] NULL,
	[criticalmicro] [varchar](1) NULL,
	[contamicro] [varchar](1) NULL,
	[microspecimensource] [varchar](50) NULL,
	[histogrossby] [varchar](50) NULL,
	[histosampletype] [varchar](1000) NULL,
	[HQCheckedBy] [varchar](50) NULL,
	[HQCGrossing] [varchar](20) NULL,
	[HQCStaining] [varchar](20) NULL,
	[HQCEmbedding] [varchar](20) NULL,
	[HQCRemark1] [varchar](255) NULL,
	[HQCRemark2] [varchar](255) NULL,
	[HQCRemark3] [varchar](255) NULL,
	[TotNoSpecimens] [int] NULL,
	[TotNoBlocks] [int] NULL,
	[TotNoSpecialStain] [int] NULL,
	[TotNoHESlides] [int] NULL,
	[TotNoIHC] [int] NULL,
	[HQCGrossingBy] [varchar](50) NULL,
	[HQCStainingBy] [varchar](50) NULL,
	[HQCEmbeddingBy] [varchar](50) NULL,
	[HQCCuttingBy] [varchar](50) NULL,
	[HQCRemark4] [varchar](250) NULL,
	[HQCCutting] [varchar](20) NULL,
	[HQCSpecStain] [varchar](20) NULL,
	[HQCIHC] [varchar](20) NULL,
	[HQCSpecStainBy] [varchar](20) NULL,
	[HQCIHCBy] [varchar](20) NULL,
	[HQCRemark5] [varchar](255) NULL,
	[HQCRemark6] [varchar](255) NULL,
	[AmentmentNo] [int] NULL,
	[histoassistby] [varchar](50) NULL,
	[TATcomment] [varchar](250) NULL,
	[inserteddate] [datetime] NULL,
 CONSTRAINT [PK_ResultTest] PRIMARY KEY CLUSTERED 
(
	[RtJobCode] ASC,
	[RtProfCode] ASC,
	[RtTestCode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, FILLFACTOR = 90, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RTSampleStatus]

-- %%
/****** Object:  Table [dbo].[RTSampleStatus]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RTSampleStatus](
	[VisitCode] [varchar](25) NOT NULL,
	[ProfCode] [int] NOT NULL,
	[TestCode] [int] NOT NULL,
	[SampleStatus] [varchar](1) NOT NULL,
	[CreationUID] [varchar](50) NOT NULL,
	[CreationDateTime] [datetime] NOT NULL,
	[UpdCompName] [varchar](25) NOT NULL,
	[Valid] [varchar](1) NOT NULL,
	[RegCenCode] [int] NULL,
	[ProcessCenCode] [int] NULL,
	[inserteddate] [datetime] NULL,
 CONSTRAINT [PK_RTSampleStatus] PRIMARY KEY CLUSTERED 
(
	[VisitCode] ASC,
	[ProfCode] ASC,
	[TestCode] ASC,
	[SampleStatus] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, FILLFACTOR = 90, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SampleStatus]

-- %%
/****** Object:  Table [dbo].[SampleStatus]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SampleStatus](
	[Status] [varchar](1) NOT NULL,
	[StatusDesc] [varchar](25) NOT NULL,
	[DispOrder] [smallint] NULL,
	[Valid] [varchar](1) NOT NULL,
 CONSTRAINT [PK_Status] PRIMARY KEY CLUSTERED 
(
	[Status] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, FILLFACTOR = 90, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Test]

-- %%
/****** Object:  Table [dbo].[Test]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Test](
	[TestCode] [smallint] IDENTITY(100,100) NOT NULL,
	[TestName] [nvarchar](255) NULL,
	[TestPrintAs] [nvarchar](255) NULL,
	[TestMethod] [nvarchar](100) NULL,
	[TestRate] [money] NULL,
	[TestCategory] [nvarchar](100) NULL,
	[TestOrder] [smallint] NULL,
	[TestSuppressNamePrint] [bit] NOT NULL,
	[TestKeepTogether] [nvarchar](1) NULL,
	[TestPageSize] [smallint] NULL,
	[TestFooter] [ntext] NULL,
	[TestHist] [smallint] NULL,
	[TestCutCategory] [nvarchar](1) NULL,
	[Cost] [money] NULL,
	[TestOutSide] [nvarchar](1) NULL,
	[vc_webUpload] [char](1) NULL,
	[hmscode] [nvarchar](250) NULL,
	[SENDSMS] [nvarchar](1) NULL,
	[accheadcode] [nchar](3) NULL,
	[ViewReport] [nvarchar](1) NULL,
	[ColorCode] [nvarchar](20) NULL,
	[SampleType] [nvarchar](30) NULL,
	[testdays] [int] NULL,
	[nabl] [char](10) NULL,
	[TestOSLabCode] [int] NULL,
	[ENABLE] [nvarchar](1) NULL,
	[REFFERALCUT] [int] NULL,
	[Testcount] [int] NULL,
	[testhist1] [int] NULL,
	[cptcode] [nvarchar](250) NULL,
	[vcencode] [int] NULL,
	[samplevol] [nvarchar](50) NULL,
	[accrediation] [nvarchar](50) NULL,
	[autoauth] [nvarchar](1) NULL,
	[TAT] [int] NULL,
	[testalias] [nvarchar](250) NULL,
	[calccptcode] [nvarchar](255) NULL,
	[microspecialcpt] [nvarchar](250) NULL,
	[histospecialcpt] [nvarchar](250) NULL,
	[WEBTESTCODE] [nvarchar](50) NULL,
	[Micro_ESBLCPT] [nvarchar](250) NULL,
	[Micro_colonyCPT] [nvarchar](250) NULL,
	[testhmscode] [nvarchar](10) NULL,
	[autocomplete] [nvarchar](1) NULL,
	[vattestcatcode] [int] NULL,
	[testschedule] [nvarchar](50) NULL,
	[TestReorder] [int] NULL,
	[SampleCollectionMethod] [nvarchar](100) NULL,
	[TATcomment] [nvarchar](max) NULL,
	[active] [bit] NULL,
	[doneby] [nvarchar](250) NULL,
	[adactivity] [nvarchar](250) NULL,
	[compname] [nvarchar](250) NULL,
	[activitydttime] [datetime] NULL,
	[TillFirstReview] [nvarchar](1) NULL,
	[Stat_TAT] [int] NULL,
	[TestProfile] [nvarchar](250) NULL,
	[ProfCode] [int] NULL,
 CONSTRAINT [PK_Test] PRIMARY KEY CLUSTERED 
(
	[TestCode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, FILLFACTOR = 90, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TestHeaderParam]

-- %%
/****** Object:  Table [dbo].[TestHeaderParam]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TestHeaderParam](
	[ThpTestCode] [smallint] NOT NULL,
	[ThpHeadCode] [smallint] NOT NULL,
	[ThpParamCode] [smallint] NOT NULL,
	[ThpPrintOrder] [smallint] NULL,
	[SENDSMS] [nvarchar](1) NULL,
	[TestParamBlank] [int] NULL,
	[ParamType] [nvarchar](1) NULL,
	[doneby] [nvarchar](250) NULL,
	[adactivity] [nvarchar](250) NULL,
	[compname] [nvarchar](250) NULL,
	[activitydttime] [datetime] NULL,
 CONSTRAINT [PK_TestHeaderParam] PRIMARY KEY CLUSTERED 
(
	[ThpTestCode] ASC,
	[ThpHeadCode] ASC,
	[ThpParamCode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, FILLFACTOR = 90, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Titles]

-- %%
/****** Object:  Table [dbo].[Titles]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Titles](
	[Title] [varchar](50) NOT NULL,
	[Gender] [varchar](1) NOT NULL,
	[DispOrder] [int] IDENTITY(1,1) NOT NULL,
	[DefaultAgeType] [nvarchar](1) NULL,
	[active] [nvarchar](1) NULL,
 CONSTRAINT [PK_Titles] PRIMARY KEY CLUSTERED 
(
	[Title] ASC,
	[Gender] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, FILLFACTOR = 90, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserCategory]

-- %%
/****** Object:  Table [dbo].[UserCategory]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserCategory](
	[UserID] [varchar](50) NOT NULL,
	[CatCode] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserRights]

-- %%
/****** Object:  Table [dbo].[UserRights]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserRights](
	[Userid] [varchar](50) NOT NULL,
	[Rights] [varchar](100) NOT NULL,
	[Groups] [varchar](50) NULL,
	[doneby] [varchar](250) NULL,
	[adactivity] [varchar](250) NULL,
	[compname] [varchar](250) NULL,
	[activitydttime] [datetime] NULL,
 CONSTRAINT [pk_rights] PRIMARY KEY CLUSTERED 
(
	[Userid] ASC,
	[Rights] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[Userid] [varchar](50) NOT NULL,
	[Password] [varchar](50) NULL,
	[UID] [int] NULL,
	[processat] [int] NULL,
	[LicenceNo] [varchar](50) NULL,
	[valid] [varchar](1) NULL,
	[LastPwdChangedt] [datetime] NULL,
	[doneby] [varchar](250) NULL,
	[adactivity] [varchar](250) NULL,
	[compname] [varchar](250) NULL,
	[activitydtime] [datetime] NULL,
	[EncPassword] [varbinary](max) NULL,
	[Id] [int] IDENTITY(1,1) NOT NULL,
 CONSTRAINT [pk_Userid] PRIMARY KEY CLUSTERED 
(
	[Userid] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Visit]

-- %%
/****** Object:  Table [dbo].[Visit]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Visit](
	[VstCode] [varchar](250) NOT NULL,
	[VstDate] [datetime] NULL,
	[VstPatCode] [real] NOT NULL,
	[VstDocCode] [real] NULL,
	[VstConsultant] [varchar](100) NULL,
	[VstDestination] [varchar](200) NULL,
	[VstXRefNo] [varchar](200) NULL,
	[VstPatType] [varchar](250) NULL,
	[VstCenCode] [int] NULL,
	[VstCenAlias] [varchar](250) NULL,
	[VstBillAmt] [money] NULL,
	[VstDeduct] [money] NULL,
	[VstTotalRate] [money] NULL,
	[VstFee] [money] NULL,
	[VstBalance] [money] NULL,
	[VstReceived] [money] NULL,
	[VstPrintOption] [varchar](250) NULL,
	[VstPageSize] [varchar](250) NULL,
	[VstRefFlag] [bit] NOT NULL,
	[VstReceipt] [varchar](250) NULL,
	[VstReceiptNo] [int] NULL,
	[VstJobOver] [bit] NULL,
	[VstTitle] [varchar](250) NULL,
	[RefNo] [varchar](250) NULL,
	[VstAddress] [varchar](255) NULL,
	[VstDispatchMode] [varchar](250) NULL,
	[Desc] [varchar](255) NULL,
	[UserId] [varchar](100) NULL,
	[Reason] [varchar](255) NULL,
	[Description] [varchar](255) NULL,
	[VstOthersReason] [varchar](250) NULL,
	[TvInvalidReason] [varchar](250) NULL,
	[VstConsumables] [money] NULL,
	[VstRefund] [money] NULL,
	[VstCenMailType] [varchar](250) NULL,
	[VstDocMailType] [varchar](250) NULL,
	[VstShowRefDr] [varchar](250) NULL,
	[VstEmail] [varchar](250) NULL,
	[VstMobile] [varchar](250) NULL,
	[BillNo] [varchar](250) NULL,
	[VstSRS] [varchar](250) NULL,
	[VstTime] [varchar](250) NULL,
	[Appt] [varchar](100) NULL,
	[VstSampleCollected] [bit] NULL,
	[AgeinDays] [int] NULL,
	[Age] [int] NULL,
	[AgeTitle] [varchar](250) NULL,
	[IPOP] [varchar](1) NULL,
	[BedNo] [varchar](250) NULL,
	[vstotherreason] [varchar](250) NULL,
	[patage] [int] NULL,
	[accheadcode] [char](250) NULL,
	[SourceCenterCode] [int] NULL,
	[RegstrationCentreCode] [int] NULL,
	[SendSMS] [varchar](1) NULL,
	[WebReportPWD] [varchar](250) NULL,
	[stat] [varchar](250) NULL,
	[initials] [varchar](250) NULL,
	[statdate] [varchar](250) NULL,
	[stattime] [varchar](250) NULL,
	[samplesource] [varchar](250) NULL,
	[extsampletime] [varchar](250) NULL,
	[history] [varchar](250) NULL,
	[smsdeliver] [varchar](250) NULL,
	[empno] [varchar](250) NULL,
	[regnno] [varchar](250) NULL,
	[pbno] [varchar](250) NULL,
	[codeno] [varchar](250) NULL,
	[opdno] [varchar](250) NULL,
	[echsno] [varchar](250) NULL,
	[badgeno] [varchar](250) NULL,
	[specimenid] [varchar](250) NULL,
	[dispatchaddress] [varchar](250) NULL,
	[vstlabno] [varchar](250) NULL,
	[claimdate] [datetime] NULL,
	[payer] [varchar](250) NULL,
	[resubmissiontype] [varchar](250) NULL,
	[resubmissioncomment] [varchar](500) NULL,
	[cardtype] [varchar](500) NULL,
	[approvalnumber] [varchar](500) NULL,
	[encounterdone] [varchar](1) NULL,
	[vstPatientTypeID] [int] NULL,
	[resubmit] [varchar](1) NULL,
	[slides] [int] NULL,
	[blocks] [int] NULL,
	[TVINVALIDDATE] [datetime] NULL,
	[calcvsttotalrate] [money] NULL,
	[calcdocrefferal] [money] NULL,
	[vstdocrefferal] [money] NULL,
	[encouterat] [datetime] NULL,
	[encounterby] [varchar](250) NULL,
	[vstpatientshare] [money] NULL,
	[VstRegDate] [datetime] NULL,
	[iscancerpatient] [varchar](1) NULL,
	[vstage] [varchar](11) NULL,
	[vstaddressbk] [varchar](5000) NULL,
	[sendsms_resultapproval] [varchar](1) NULL,
	[vstinssamplestatus] [varchar](1) NULL,
	[regstatus] [varchar](50) NULL,
	[eclaimrecvd] [money] NULL,
	[eclaimclose] [int] NULL,
	[vstpendingclaimcomment] [varchar](250) NULL,
	[vstReclaimamt] [money] NULL,
	[rsversionno] [int] NULL,
	[vsttopup] [varchar](1) NULL,
	[vsttopupperc] [int] NULL,
	[vsttopupjobcode] [varchar](15) NULL,
	[vstenddate] [datetime] NULL,
	[vstvat] [money] NULL,
	[vstvatrecover] [varchar](1) NULL,
	[vstvatclientcategory] [int] NULL,
	[vstclientvatperc] [int] NULL,
	[vstsenderId] [varchar](50) NULL,
	[epriorrequest] [bit] NULL,
	[epriorrequestEmail] [bit] NULL,
	[AdmSrc] [varchar](100) NULL,
	[DispositionDisp] [varchar](100) NULL,
	[AdmitDatetime] [datetime] NULL,
	[IntLabComment] [varchar](250) NULL,
	[IsVIPPatient] [varchar](10) NULL,
	[FreezeBill] [bit] NULL,
 CONSTRAINT [PK_Visit] PRIMARY KEY CLUSTERED 
(
	[VstCode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, FILLFACTOR = 90, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF_email]

-- %%
ALTER TABLE [dbo].[Doctor] ADD  CONSTRAINT [DF_email]  DEFAULT (N'phdbarsha@proficiencylab.org') FOR [EMail]
GO

-- %% [markdown]
-- # [DF__Doctor__doctorre__690797E6]

-- %%
ALTER TABLE [dbo].[Doctor] ADD  DEFAULT ('SINGLE') FOR [doctorreftype]
GO

-- %% [markdown]
-- # [DF__Doctor__uploadon__69FBBC1F]

-- %%
ALTER TABLE [dbo].[Doctor] ADD  DEFAULT ('Y') FOR [uploadonweb]
GO

-- %% [markdown]
-- # [DF_Param_pPrecision_1]

-- %%
ALTER TABLE [dbo].[Param] ADD  CONSTRAINT [DF_Param_pPrecision_1]  DEFAULT ((-1)) FOR [pPrecision]
GO

-- %% [markdown]
-- # [DF_Param_observationresult]

-- %%
ALTER TABLE [dbo].[Param] ADD  CONSTRAINT [DF_Param_observationresult]  DEFAULT ((0)) FOR [observationresult]
GO

-- %% [markdown]
-- # [DF__Param__observati__503BEA1C]

-- %%
ALTER TABLE [dbo].[Param] ADD  DEFAULT ('') FOR [observationunit]
GO

-- %% [markdown]
-- # [DF_ParamNormalRange_ParamDefault]

-- %%
ALTER TABLE [dbo].[ParamNormalRange] ADD  CONSTRAINT [DF_ParamNormalRange_ParamDefault]  DEFAULT ((0)) FOR [ParamDefault]
GO

-- %% [markdown]
-- # [DF__Patient__inserte__276EDEB3]

-- %%
ALTER TABLE [dbo].[Patient] ADD  DEFAULT (getdate()) FOR [inserteddate]
GO

-- %% [markdown]
-- # [DF_Result_AbnormalFlag]

-- %%
ALTER TABLE [dbo].[Result] ADD  CONSTRAINT [DF_Result_AbnormalFlag]  DEFAULT ('N') FOR [AbnormalFlag]
GO

-- %% [markdown]
-- # [DF_Result_status]

-- %%
ALTER TABLE [dbo].[Result] ADD  CONSTRAINT [DF_Result_status]  DEFAULT ('H') FOR [status]
GO

-- %% [markdown]
-- # [DF_Result_crilow]

-- %%
ALTER TABLE [dbo].[Result] ADD  CONSTRAINT [DF_Result_crilow]  DEFAULT ((0)) FOR [crilow]
GO

-- %% [markdown]
-- # [DF_Result_crihigh]

-- %%
ALTER TABLE [dbo].[Result] ADD  CONSTRAINT [DF_Result_crihigh]  DEFAULT ((0)) FOR [crihigh]
GO

-- %% [markdown]
-- # [DF__Result__c6ktests__440B1D61]

-- %%
ALTER TABLE [dbo].[Result] ADD  DEFAULT ('G') FOR [c6ktestsent]
GO

-- %% [markdown]
-- # [DF__Result__c6kAtest__44FF419A]

-- %%
ALTER TABLE [dbo].[Result] ADD  DEFAULT ('G') FOR [c6kAtestsent]
GO

-- %% [markdown]
-- # [DF__Result__TRDELTAF__45F365D3]

-- %%
ALTER TABLE [dbo].[Result] ADD  DEFAULT ('N') FOR [TRDELTAFAILED]
GO

-- %% [markdown]
-- # [DF__Result__inserted__46E78A0C]

-- %%
ALTER TABLE [dbo].[Result] ADD  DEFAULT (getdate()) FOR [inserteddate]
GO

-- %% [markdown]
-- # [DF__Result2__inserte__48CFD27E]

-- %%
ALTER TABLE [dbo].[Result2] ADD  DEFAULT (getdate()) FOR [inserteddate]
GO

-- %% [markdown]
-- # [DF_ResultTest_RtRate]

-- %%
ALTER TABLE [dbo].[ResultTest] ADD  CONSTRAINT [DF_ResultTest_RtRate]  DEFAULT ((0)) FOR [RtRate]
GO

-- %% [markdown]
-- # [DF_ResultTest_TestCount]

-- %%
ALTER TABLE [dbo].[ResultTest] ADD  CONSTRAINT [DF_ResultTest_TestCount]  DEFAULT ((1)) FOR [RtTestCount]
GO

-- %% [markdown]
-- # [DF_ResultTest_SENDFAX]

-- %%
ALTER TABLE [dbo].[ResultTest] ADD  CONSTRAINT [DF_ResultTest_SENDFAX]  DEFAULT ('N') FOR [SENDFAX]
GO

-- %% [markdown]
-- # [DF__ResultTes__PROCE__4E88ABD4]

-- %%
ALTER TABLE [dbo].[ResultTest] ADD  DEFAULT ('N') FOR [PROCESSED]
GO

-- %% [markdown]
-- # [DF__ResultTes__rtint__2B554987]

-- %%
ALTER TABLE [dbo].[ResultTest] ADD  CONSTRAINT [DF__ResultTes__rtint__2B554987]  DEFAULT ((1)) FOR [rtintest]
GO

-- %% [markdown]
-- # [DF_ResultTest_sendfax1]

-- %%
ALTER TABLE [dbo].[ResultTest] ADD  CONSTRAINT [DF_ResultTest_sendfax1]  DEFAULT ('Y') FOR [sendfax1]
GO

-- %% [markdown]
-- # [DF__ResultTes__micro__5165187F]

-- %%
ALTER TABLE [dbo].[ResultTest] ADD  DEFAULT ('N') FOR [microesbl]
GO

-- %% [markdown]
-- # [DF__ResultTes__Inssa__52593CB8]

-- %%
ALTER TABLE [dbo].[ResultTest] ADD  DEFAULT ('A') FOR [Inssamplestatus]
GO

-- %% [markdown]
-- # [DF__ResultTes__rtsta__534D60F1]

-- %%
ALTER TABLE [dbo].[ResultTest] ADD  DEFAULT (getdate()) FOR [rtstartdate]
GO

-- %% [markdown]
-- # [DF__ResultTes__rtvat__5441852A]

-- %%
ALTER TABLE [dbo].[ResultTest] ADD  DEFAULT ('0') FOR [rtvat]
GO

-- %% [markdown]
-- # [DF__ResultTes__rtvat__5535A963]

-- %%
ALTER TABLE [dbo].[ResultTest] ADD  DEFAULT ('0') FOR [rtvatperc]
GO

-- %% [markdown]
-- # [DF__ResultTes__rtins__5629CD9C]

-- %%
ALTER TABLE [dbo].[ResultTest] ADD  DEFAULT ('-1') FOR [rtinsfactor]
GO

-- %% [markdown]
-- # [DF__ResultTes__inser__571DF1D5]

-- %%
ALTER TABLE [dbo].[ResultTest] ADD  DEFAULT (getdate()) FOR [inserteddate]
GO

-- %% [markdown]
-- # [DF_RTSampleStatus_ProfCode]

-- %%
ALTER TABLE [dbo].[RTSampleStatus] ADD  CONSTRAINT [DF_RTSampleStatus_ProfCode]  DEFAULT ((9999)) FOR [ProfCode]
GO

-- %% [markdown]
-- # [DF__RTSampleS__inser__3A81B327]

-- %%
ALTER TABLE [dbo].[RTSampleStatus] ADD  DEFAULT (getdate()) FOR [inserteddate]
GO

-- %% [markdown]
-- # [DF__SampleSta__Valid__3D5E1FD2]

-- %%
ALTER TABLE [dbo].[SampleStatus] ADD  DEFAULT ('Y') FOR [Valid]
GO

-- %% [markdown]
-- # [DF__TEST__ViewReport__452A2A23]

-- %%
ALTER TABLE [dbo].[Test] ADD  CONSTRAINT [DF__TEST__ViewReport__452A2A23]  DEFAULT ('Y') FOR [ViewReport]
GO

-- %% [markdown]
-- # [DF_Test_testdays]

-- %%
ALTER TABLE [dbo].[Test] ADD  CONSTRAINT [DF_Test_testdays]  DEFAULT ((1)) FOR [testdays]
GO

-- %% [markdown]
-- # [DF_Test_Testcount]

-- %%
ALTER TABLE [dbo].[Test] ADD  CONSTRAINT [DF_Test_Testcount]  DEFAULT ((1)) FOR [Testcount]
GO

-- %% [markdown]
-- # [DF__Test__Micro_ESBL__41EDCAC5]

-- %%
ALTER TABLE [dbo].[Test] ADD  DEFAULT ('') FOR [Micro_ESBLCPT]
GO

-- %% [markdown]
-- # [DF__Test__Micro_colo__42E1EEFE]

-- %%
ALTER TABLE [dbo].[Test] ADD  DEFAULT ('') FOR [Micro_colonyCPT]
GO

-- %% [markdown]
-- # [DF__Test__SampleColl__43D61337]

-- %%
ALTER TABLE [dbo].[Test] ADD  DEFAULT ('') FOR [SampleCollectionMethod]
GO

-- %% [markdown]
-- # [DF__Test__TATcomment__44CA3770]

-- %%
ALTER TABLE [dbo].[Test] ADD  DEFAULT ('') FOR [TATcomment]
GO

-- %% [markdown]
-- # [DF_activitydttime]

-- %%
ALTER TABLE [dbo].[Test] ADD  CONSTRAINT [DF_activitydttime]  DEFAULT (getdate()) FOR [activitydttime]
GO

-- %% [markdown]
-- # [DF__Test__Stat_TAT__46B27FE2]

-- %%
ALTER TABLE [dbo].[Test] ADD  DEFAULT ((0)) FOR [Stat_TAT]
GO

-- %% [markdown]
-- # [DF__Titles__active__15DA3E5D]

-- %%
ALTER TABLE [dbo].[Titles] ADD  DEFAULT ('1') FOR [active]
GO

-- %% [markdown]
-- # [DF_LPCD]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_LPCD]  DEFAULT (getdate()) FOR [LastPwdChangedt]
GO

-- %% [markdown]
-- # [DF_ABT]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_ABT]  DEFAULT (getdate()) FOR [activitydtime]
GO

-- %% [markdown]
-- # [DF_Visit_VstAddress]

-- %%
ALTER TABLE [dbo].[Visit] ADD  CONSTRAINT [DF_Visit_VstAddress]  DEFAULT ((0)) FOR [VstAddress]
GO

-- %% [markdown]
-- # [DF_Visit_VstTime]

-- %%
ALTER TABLE [dbo].[Visit] ADD  CONSTRAINT [DF_Visit_VstTime]  DEFAULT ((0)) FOR [VstTime]
GO

-- %% [markdown]
-- # [DF_Visit_Appt]

-- %%
ALTER TABLE [dbo].[Visit] ADD  CONSTRAINT [DF_Visit_Appt]  DEFAULT ('N') FOR [Appt]
GO

-- %% [markdown]
-- # [DF_Visit_VstSampleCollected]

-- %%
ALTER TABLE [dbo].[Visit] ADD  CONSTRAINT [DF_Visit_VstSampleCollected]  DEFAULT ((0)) FOR [VstSampleCollected]
GO

-- %% [markdown]
-- # [DF_Visit_AgeInDays]

-- %%
ALTER TABLE [dbo].[Visit] ADD  CONSTRAINT [DF_Visit_AgeInDays]  DEFAULT ((0)) FOR [AgeinDays]
GO

-- %% [markdown]
-- # [DF_Visit_encounterdone]

-- %%
ALTER TABLE [dbo].[Visit] ADD  CONSTRAINT [DF_Visit_encounterdone]  DEFAULT ('N') FOR [encounterdone]
GO

-- %% [markdown]
-- # [DF_VstRegDate]

-- %%
ALTER TABLE [dbo].[Visit] ADD  CONSTRAINT [DF_VstRegDate]  DEFAULT (getdate()) FOR [VstRegDate]
GO

-- %% [markdown]
-- # [DF__Visit__sendsms_r__30F848ED]

-- %%
ALTER TABLE [dbo].[Visit] ADD  DEFAULT ('N') FOR [sendsms_resultapproval]
GO

-- %% [markdown]
-- # [DF__Visit__vstinssam__31EC6D26]

-- %%
ALTER TABLE [dbo].[Visit] ADD  DEFAULT ('A') FOR [vstinssamplestatus]
GO

-- %% [markdown]
-- # [C_eclaimclose]

-- %%
ALTER TABLE [dbo].[Visit] ADD  CONSTRAINT [C_eclaimclose]  DEFAULT ((0)) FOR [eclaimclose]
GO

-- %% [markdown]
-- # [DF__Visit__vstvat__33D4B598]

-- %%
ALTER TABLE [dbo].[Visit] ADD  DEFAULT ('0') FOR [vstvat]
GO

-- %% [markdown]
-- # [DF__Visit__vstclient__34C8D9D1]

-- %%
ALTER TABLE [dbo].[Visit] ADD  DEFAULT ((0)) FOR [vstclientvatperc]
GO

-- %% [markdown]
-- # [DF__Visit__epriorreq__35BCFE0A]

-- %%
ALTER TABLE [dbo].[Visit] ADD  DEFAULT ((1)) FOR [epriorrequest]
GO

-- %% [markdown]
-- # [DF__Visit__epriorreq__36B12243]

-- %%
ALTER TABLE [dbo].[Visit] ADD  DEFAULT ((1)) FOR [epriorrequestEmail]
GO

-- %% [markdown]
-- # [dbo].[Sp_CreateTest]

-- %%
/****** Object:  StoredProcedure [dbo].[Sp_CreateTest]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[Sp_CreateTest]   
(    
@pJsonData nvarchar(max),@pRid int out,@pResult varchar(250) out    
)    
as    
BEGIN  
Begin Try
Set NoCount Off  
Declare @IsJson int,@TestName varchar(30)    
SET @pResult = ''     
Set @IsJson= (Select ISJSON(@pJsonData))    
if(@IsJson=1)    
Begin    
Select * into #Test from openjson(@pJsonData) with     
(    
TestName nVarchar(255),TestPrintAs nvarchar(255),TestMethod nvarchar(255),TestRate Money,  
TestCategory Varchar(100),TestOrder int,TestSuppressNamePrint int,TestKeepTogether Varchar(1),  
TestPageSize int,TestFooter Varchar(500),TestCutCategory Varchar(1),Cost Money,TestOutSide varchar(1),  
hmscode varchar(250),SENDSMS varchar(1),ViewReport Varchar(1),SampleType Varchar(30),testdays int,  
TestOSLabCode int,Testcount int,cptcode varchar(250),vcencode int,samplevol varchar(50),  
accrediation varchar(50),autoauth varchar(1),TAT int,testalias varchar(250),calccptcode varchar(255),  
microspecialcpt varchar(255),histospecialcpt varchar(250),WEBTESTCODE varchar(50),Micro_ESBLCPT varchar(50),  
Micro_colonyCPT varchar(250),testhmscode varchar(10),autocomplete varchar(1),vattestcatcode int,testschedule varchar(50),  
TestReorder int,SampleCollectionMethod varchar(100),doneby varchar(250),adactivity varchar(250),compname varchar(250)  
)   
  
Set @TestName =(Select TestName from #Test)  
  
  
if exists(Select * from Test where TestName=@TestName)    
    Begin    
     SET @pResult =  'TestName already Exists';              
     SET @pRid=-1    
    End    
else  
Begin  
Insert into Test(  
TestName ,TestPrintAs,TestMethod,TestRate,  
TestCategory ,TestOrder ,TestSuppressNamePrint,TestKeepTogether,  
TestPageSize,TestFooter,TestCutCategory,Cost,TestOutSide,  
hmscode ,SENDSMS ,ViewReport,SampleType,testdays,  
TestOSLabCode,Testcount,cptcode,vcencode,samplevol,  
accrediation,autoauth,TAT,testalias,calccptcode,  
microspecialcpt ,histospecialcpt ,WEBTESTCODE,Micro_ESBLCPT,  
Micro_colonyCPT,testhmscode,autocomplete,vattestcatcode,testschedule,  
TestReorder,SampleCollectionMethod ,doneby,adactivity,compname)  
  
Select   
TestName ,TestPrintAs,TestMethod,TestRate,  
TestCategory ,TestOrder ,TestSuppressNamePrint,TestKeepTogether,  
TestPageSize,TestFooter,TestCutCategory,Cost,TestOutSide,  
hmscode ,SENDSMS ,ViewReport,SampleType,testdays,  
TestOSLabCode,Testcount,cptcode,vcencode,samplevol,  
accrediation,autoauth,TAT,testalias,calccptcode,  
microspecialcpt ,histospecialcpt ,WEBTESTCODE,Micro_ESBLCPT,  
Micro_colonyCPT,testhmscode,autocomplete,vattestcatcode,testschedule,  
TestReorder,SampleCollectionMethod ,doneby,'Add New Test',compname from #Test  
  
Insert Into AuditLog(ActionType,UserId,NewValue,Alcompname)
Select 'Add New Test',doneby,TestName,Compname from #Test

     SET @pResult =  'Test Created Sucussfully';              
     SET @pRid=@@IDENTITY   


end  
End  
else    
begin   
  SET @pResult =  'Error in JSON file.';              
  SET @pRid=0     
end  
End Try
BEGIN CATCH
DECLARE @MESSAGE AS VARCHAR(500)= CONCAT('ERROR_MESSAGE - ',ERROR_MESSAGE(),'ERROR_LINE - ',ERROR_LINE(),'ERROR_NUMBER - ',ERROR_NUMBER(),'ERROR_SEVERITY - ',ERROR_SEVERITY(),'ERROR_PROCEDURE - ',ERROR_PROCEDURE())  
RAISERROR(@MESSAGE,16,1);
END CATCH 
END  
  
  
  
Select * from Test
GO

-- %% [markdown]
-- # [dbo].[Sp_DeleteOSLab]

-- %%
/****** Object:  StoredProcedure [dbo].[Sp_DeleteOSLab]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[Sp_DeleteOSLab]
(
@OSLabName varchar(100),@pRid int output,@pResult varchar(250)output
)
as
BEGIN
Set Nocount Off;
BEGIN TRY
Set @pResult=''
if exists(Select * from OSLABMASTER where OSLabName=@OSLabName)
Begin

Delete OSLABMASTER where OSLabName=@OSLabName
	          set @pResult='Lab  Name Deleted Sucessfully';
	          set @pRid=-2
              
End
else
Begin
              SET @pResult =  'Lab Name does not exists';         
			  SET @pRid=-1	
End
END TRY
BEGIN CATCH
    DECLARE @MESSAGE AS VARCHAR(500)= CONCAT('ERROR_MESSAGE - ',ERROR_MESSAGE(),'ERROR_LINE - ',ERROR_LINE(),'ERROR_NUMBER - ',ERROR_NUMBER(),'ERROR_SEVERITY - ',ERROR_SEVERITY(),'ERROR_PROCEDURE - ',ERROR_PROCEDURE())  
    RAISERROR(@MESSAGE,16,1);
END CATCH 
END
GO

-- %% [markdown]
-- # [dbo].[Sp_DeleteReasons]

-- %%
/****** Object:  StoredProcedure [dbo].[Sp_DeleteReasons]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Proc [dbo].[Sp_DeleteReasons]
(
@Reason varchar(250),@pResult varchar(250) output,@pRid int output
)
as
Begin
set nocount off;
Begin Try
Set @pResult=''
if exists(Select * from Reason where Reason=@Reason)
begin
 Delete Reason where Reason=@Reason
 set  @pResult='Reason Deleted Sucessfully';
 set @pRid=-2
 end
 else
 begin
 set  @pResult='Invalid Reason';
 set @pRid=-1
 end
 end Try
 BEGIN CATCH
    DECLARE @MESSAGE AS VARCHAR(500)= CONCAT('ERROR_MESSAGE - ',ERROR_MESSAGE(),'ERROR_LINE - ',ERROR_LINE(),'ERROR_NUMBER - ',ERROR_NUMBER(),'ERROR_SEVERITY - ',ERROR_SEVERITY(),'ERROR_PROCEDURE - ',ERROR_PROCEDURE())  
    RAISERROR(@MESSAGE,16,1);
END CATCH 
End



GO

-- %% [markdown]
-- # [dbo].[Sp_DeleteTest]

-- %%
/****** Object:  StoredProcedure [dbo].[Sp_DeleteTest]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[Sp_DeleteTest]
(
@TestName varchar(250),@pResult varchar(250) output,@pRid int output
)
as
Begin
set nocount off;
Begin Try
Set @pResult=''
if exists(Select * from Test where TestName=@TestName)
begin
 Delete Test where TestName=@TestName
 set  @pResult='Test Deleted Sucessfully';
 set @pRid=-2
 end
 else
 begin
 set  @pResult='Invalid TestName';
 set @pRid=-1
 end
 end Try
 BEGIN CATCH
    DECLARE @MESSAGE AS VARCHAR(500)= CONCAT('ERROR_MESSAGE - ',ERROR_MESSAGE(),'ERROR_LINE - ',ERROR_LINE(),'ERROR_NUMBER - ',ERROR_NUMBER(),'ERROR_SEVERITY - ',ERROR_SEVERITY(),'ERROR_PROCEDURE - ',ERROR_PROCEDURE())  
    RAISERROR(@MESSAGE,16,1);
END CATCH 
End



GO

-- %% [markdown]
-- # [dbo].[sp_GetTitle]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_GetTitle]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[sp_GetTitle]
as
Begin
begin Try
select * from Titles
End Try
BEGIN CATCH
    DECLARE @MESSAGE AS VARCHAR(500)= CONCAT('ERROR_MESSAGE - ',ERROR_MESSAGE(),'ERROR_LINE - ',ERROR_LINE(),'ERROR_NUMBER - ',ERROR_NUMBER(),'ERROR_SEVERITY - ',ERROR_SEVERITY(),'ERROR_PROCEDURE - ',ERROR_PROCEDURE())  
    RAISERROR(@MESSAGE,16,1);
END CATCH 
End
GO

-- %% [markdown]
-- # [dbo].[Sp_InsertOSLab]

-- %%
/****** Object:  StoredProcedure [dbo].[Sp_InsertOSLab]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[Sp_InsertOSLab]
(
@pJsonData nvarchar(max),@pRid int output,@pResult varchar(250) output
)
as
BEGIN
SET NOCOUNT OFF;
Declare @IsJson int,@OSLabName varchar(30)  
Begin Try
SET @pResult = ''       
Set @IsJson= (Select ISJSON(@pJsonData))  
if(@IsJson=1)
Begin
Select * into #OSLABMASTER from openjson(@pJsonData) with 
(
OSLabName varchar(100),OSContactPerson varchar(50),
OSAddress varchar(255),OSPhone1 varchar(30),OSPhone2 varchar(30),OSFax varchar(20),OSEmailID Varchar(30),
Valid varchar(1),IsReffered varchar(1)
)

if exists(Select  * from OSLabMaster where OSLabName=@OSLabName)
   Begin 
      SET @pResult =  'OSLab already Exists';                
      SET @pRid=-1    
     End
else
Begin

Insert into OSLABMASTER(OsLabname,OSContactPerson,OSAddress,OSPhone1,OSPhone2,OSFax,OSEmailID,Valid,IsReffered)
(Select OSLabName,OSContactPerson,OSAddress,OSPhone1,OSPhone2,OSFax,OSEmailID,Valid,IsReffered from #OSLABMASTER)
      SET @pResult =  'OsLab Inserted Sucessfully';                
      SET @pRid=@@IDENTITY    

End
End
else
Begin 
  SET @pResult =  'Error in JSON file.';                
  SET @pRid=0   
end
End Try
BEGIN CATCH
    DECLARE @MESSAGE AS VARCHAR(500)= CONCAT('ERROR_MESSAGE - ',ERROR_MESSAGE(),'ERROR_LINE - ',ERROR_LINE(),'ERROR_NUMBER - ',ERROR_NUMBER(),'ERROR_SEVERITY - ',ERROR_SEVERITY(),'ERROR_PROCEDURE - ',ERROR_PROCEDURE())  
    RAISERROR(@MESSAGE,16,1);
END CATCH 

END
GO

-- %% [markdown]
-- # [dbo].[Sp_InsertParam]

-- %%
/****** Object:  StoredProcedure [dbo].[Sp_InsertParam]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[Sp_InsertParam]
(
@pJsonData nvarchar(max),@pRid int output,@pResult varchar(250) output
)
as
Begin
Set NoCount Off;
Begin Try
Declare @Paramname nvarchar(250),@IsJson int
SET @pResult = ''   
Set @IsJson= (Select ISJSON(@pJsonData))    
if(@IsJson=1)    
Begin    
Select * into #Param  from openjson(@pJsonData) with 
(ParamName nvarchar(100),ParamPrintHead nvarchar(100),ParamUnit nvarchar(150),
	ParamMethod nvarchar(100),
	ParamRate money,
	ParamMaleNormal nvarchar(255),
	ParamFemaleNormal nvarchar(255),
	ParamChild1Normal nvarchar(255),
	ParamChild6Normal nvarchar(255) ,
	ParamChildNormal nvarchar(255) ,
	ParamMaleDef nvarchar(255) ,
	ParamFemaleDef nvarchar(255) ,
	ParamChild1Def nvarchar(255) ,
	ParamChild6Def nvarchar(255) ,
	ParamChildDef nvarchar(255) ,
	ParamMaleHigh nvarchar(255) ,
	ParamFemaleHigh nvarchar(255) ,
	ParamChild1High nvarchar(255) ,
	ParamChild6High nvarchar(255) ,
	ParamChildHigh nvarchar(255) ,
	ParamMaleLow nvarchar(255) ,
	ParamFemaleLow nvarchar(255) ,
	ParamChild1Low nvarchar(255) ,
	ParamChild6Low nvarchar(255) ,
	ParamChildLow nvarchar(255) ,
	ParamValidFlag nvarchar(50) ,
	ParamDef2 nvarchar(255) ,
	ParamFooter nvarchar(255) ,
	pPrecision smallint ,
	SENDSMS nvarchar(1) ,
	Formula nvarchar(250) ,
	DC nvarchar(1) ,
	ParamType nvarchar(1) ,
	observation nvarchar(50) ,
	observationcode nvarchar(50) ,
	SIFACTOR nvarchar(50) ,
	SIUNIT nvarchar(50) ,
	suffix  nvarchar(50),
	SampleType nvarchar(255),
	paramhmscode nvarchar(50) ,
	accrediation nvarchar(50) ,
	hmscode nvarchar(250) ,
	OBSERVATIONCPT nvarchar(100) ,
	ForNonReport bit ,
	isMandatory bit ,
	Usehelpvalue bit ,
	reportingunit nvarchar(10)
)

set @Paramname=(Select ParamName from #Param)

If exists(Select * from Param where ParamName=@Paramname)
Begin    
     SET @pResult =  'ParamName already Exists';              
     SET @pRid=-1    
    End   
else
begin
Insert into param 
(ParamName,
	ParamPrintHead,
	ParamUnit,
	ParamMethod,
	ParamRate,
	ParamMaleNormal,
	ParamFemaleNormal,
	ParamChild1Normal,
	ParamChild6Normal,
	ParamChildNormal,
	ParamMaleDef,
	ParamFemaleDef,
	ParamChild1Def,
	ParamChild6Def,
	ParamChildDef,
	ParamMaleHigh,
	ParamFemaleHigh,
	ParamChild1High,
	ParamChild6High,
	ParamChildHigh,
	ParamMaleLow,
	ParamFemaleLow,
	ParamChild1Low,
	ParamChild6Low,
	ParamChildLow,
	ParamValidFlag,
	ParamDef2,
	ParamFooter,
	pPrecision,
	SENDSMS,
	Formula,
	DC,
	ParamType,
	observation,
	observationcode,
	SIFACTOR,
	SIUNIT,
	suffix,
	SampleType,
	paramhmscode,
	accrediation,
	hmscode,
	OBSERVATIONCPT,
	ForNonReport,
	isMandatory,
	Usehelpvalue,
	reportingunit)
select 
ParamName,
	ParamPrintHead,
	ParamUnit,
	ParamMethod,
	ParamRate,
	ParamMaleNormal,
	ParamFemaleNormal,
	ParamChild1Normal,
	ParamChild6Normal,
	ParamChildNormal,
	ParamMaleDef,
	ParamFemaleDef,
	ParamChild1Def,
	ParamChild6Def,
	ParamChildDef,
	ParamMaleHigh,
	ParamFemaleHigh,
	ParamChild1High,
	ParamChild6High,
	ParamChildHigh,
	ParamMaleLow,
	ParamFemaleLow,
	ParamChild1Low,
	ParamChild6Low,
	ParamChildLow,
	ParamValidFlag,
	ParamDef2,
	ParamFooter,
	pPrecision,
	SENDSMS,
	Formula,
	DC,
	ParamType,
	observation,
	observationcode,
	SIFACTOR,
	SIUNIT,
	suffix,
	SampleType,
	paramhmscode,
	accrediation,
	hmscode,
	OBSERVATIONCPT,
	ForNonReport,
	isMandatory,
	Usehelpvalue,
	reportingunit from #Param

	  SET @pResult =  'Param Created Sucussfully';              
      SET @pRid=@@IDENTITY   
end
end
else    
begin   
  SET @pResult =  'Error in JSON file.';              
  SET @pRid=0     
end 
End Try
Begin Catch
DECLARE @MESSAGE AS VARCHAR(500)= CONCAT('ERROR_MESSAGE - ',ERROR_MESSAGE(),'ERROR_LINE - ',ERROR_LINE(),'ERROR_NUMBER - ',ERROR_NUMBER(),'ERROR_SEVERITY - ',ERROR_SEVERITY(),'ERROR_PROCEDURE - ',ERROR_PROCEDURE())  
RAISERROR(@MESSAGE,16,1);
END CATCH 
End
GO

-- %% [markdown]
-- # [dbo].[Sp_InsertReasons]

-- %%
/****** Object:  StoredProcedure [dbo].[Sp_InsertReasons]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[Sp_InsertReasons]
(
@pJsonData nvarchar(max),@pRid int output,@pResult varchar(250) output
)
as
BEGIN
SET NOCOUNT OFF;
Begin Try
Declare @IsJson int,@Reason nvarchar(255);
SET @pResult = '' ;     
Set @IsJson= (Select ISJSON(@pJsonData));  

if(@IsJson=1)
Begin
Select * into #Reason from openjson(@pJsonData) with 
(
Reason nvarchar(255),ReasonFlag nvarchar(2)
)

IF EXISTS ( SELECT 1 FROM Reason WHERE Reason IN (SELECT Reason FROM #Reason))
            BEGIN
                SET @pResult = 'Duplicate Entry Not Allowed';
                SET @pRid = -1;
            END
else
Begin
      Insert into Reason(Reason,ReasonFlag)
     (Select Reason,ReasonFlag from #Reason)
      SET @pResult ='Reason Added Sucessfully';                
      SET @pRid=1  

	  drop table #Reason;
End
End

else
Begin 
  SET @pResult =  'Error in JSON file.';                
  SET @pRid=0   
end
End Try



BEGIN CATCH
    DECLARE @MESSAGE AS VARCHAR(500)= CONCAT('ERROR_MESSAGE - ',ERROR_MESSAGE(),'ERROR_LINE - ',ERROR_LINE(),'ERROR_NUMBER - ',ERROR_NUMBER(),'ERROR_SEVERITY - ',ERROR_SEVERITY(),'ERROR_PROCEDURE - ',ERROR_PROCEDURE())  
    RAISERROR(@MESSAGE,16,1);
END CATCH 

END
GO

-- %% [markdown]
-- # [dbo].[Sp_InsertTitle]

-- %%
/****** Object:  StoredProcedure [dbo].[Sp_InsertTitle]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[Sp_InsertTitle]
(
@pJsonData nvarchar(max),@pRid int output,@pResult varchar(250) output
)
as
BEGIN
SET NOCOUNT OFF;
Declare @IsJson int,@Title varchar(30)  
Begin Try
SET @pResult = ''       
Set @IsJson= (Select ISJSON(@pJsonData))  
if(@IsJson=1)
Begin
Select * into #Titles from openjson(@pJsonData) with 
(
Title varchar(50),Gender varchar(1),DefaultAgeType varchar(1),
active int
)

if exists(Select  * from Titles where Title=@Title)
   Begin 
      SET @pResult =  'Title already Present';                
      SET @pRid=-1    
     End
else
Begin

Insert into Titles(Title,Gender,DefaultAgeType,active)
(Select Title,Gender,DefaultAgeType,active from #Titles)
      SET @pResult =  'Title Inserted Sucessfully';                
      SET @pRid=@@IDENTITY    

End
End
else
Begin 
  SET @pResult =  'Error in JSON file.';                
  SET @pRid=0   
end
End Try
BEGIN CATCH
    DECLARE @MESSAGE AS VARCHAR(500)= CONCAT('ERROR_MESSAGE - ',ERROR_MESSAGE(),'ERROR_LINE - ',ERROR_LINE(),'ERROR_NUMBER - ',ERROR_NUMBER(),'ERROR_SEVERITY - ',ERROR_SEVERITY(),'ERROR_PROCEDURE - ',ERROR_PROCEDURE())  
    RAISERROR(@MESSAGE,16,1);
END CATCH 

END
GO

-- %% [markdown]
-- # [dbo].[Sp_InsertUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[Sp_InsertUsers]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[Sp_InsertUsers]
(
@pJsonData nvarchar(max),@pRid int out,@pResult varchar(250) out
)
as
BEGIN
Set Nocount Off
Declare @IsJson int,@Userid varchar(30)
SET @pResult = ''

Set @IsJson= (Select ISJSON(@pJsonData))
if(@IsJson=1)
Begin
Select * into #Users from openjson(@pJsonData) with 
(
Userid	varchar(50),Password varchar(50),UID int,processat int,LicenceNo varchar(50),valid varchar(1),
compname varchar(250)
)


Set @Userid=(Select Userid from #Users)

if exists(Select * from Users where Userid=@Userid)
    Begin
	    SET @pResult =  'LoginName already Exists';          
		SET @pRid=-1
    End
	else
	Begin
	   Insert into Users(Userid,Password,UID,processat,LicenceNo,valid,compname)
	    Select Userid,Password,UID,processat,LicenceNo,valid,compname from #Users
	    SET @pResult =  'User Created Sucussfully';          
		SET @pRid=@@IDENTITY
	End
End
else
BEGIN
		SET @pResult =  'Error in JSON file.';          
		SET @pRid=0 
END
END
GO

-- %% [markdown]
-- # [dbo].[Sp_ProcPSGetPatDtlForSamplColl]

-- %%
/****** Object:  StoredProcedure [dbo].[Sp_ProcPSGetPatDtlForSamplColl]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[Sp_ProcPSGetPatDtlForSamplColl]
(
@Vstdate datetime, @Status as varchar(1),@IPOPNo Varchar(15), @ReqNo Varchar(15),              
@UserID Varchar(20),@CatCode Varchar(5) , @CentresCode Varchar(10),
@sampletype varchar(100)   ,@grefby varchar(50) ,@stat varchar(1), 
@isfileno int =0   
)
as
Begin
set nocount off
Begin Try

Declare @statusflag varchar(250)
If
@status='D'
Begin
set @statusflag='D'
End
else if @Status='F'
begin
set @statusflag='F'
end
else
begin
set @statusflag='%'
end


If @statusflag='D' and @statusflag='%'
begin

Select v.vstcode,v.vstdate,v.vstdestination as vstdestination,v.IsVIPPatient,
p.PatName,p.Patsex,P.Patcode,v.refno as IPopNO
from Visit v
inner join Patient p on p.patcode=v.vstpatcode
inner join Resulttest rt  on rt.rtjobcode=v.vstcode
inner join Category c on rt.rtcat=c.category
inner join Usercategory uc on uc.catcode=c.catcode
where v.VstReceipt<>'I'
and  v.Vstdate>=@Vstdate and v.Vstdate<=@Vstdate
and v.Refno =@ReqNo or v.vstdestination=@ReqNo
and uc.Userid=@UserID and C.catcode=@CatCode
and isnull(rt.samplestatus ,'D') like @statusflag
and V.Regstrationcentrecode=@CentresCode
order by v.vstdestination desc,v.vstdate desc
end

else if  @ReqNo='%'
begin
Select  v.vstdestination,v.vstdate,p.PatName,p.Pattitle,
P.PatSex,v.ISVIPPatient,p.Patcode from Visit v
inner join Patient p on v.vstpatcode =p.patcode
inner join Resulttest rt on rt.rtjobcode=v.vstcode
inner join Category c on rt.rtcat=c.category
inner join Usercategory uc on uc.catcode=c.catcode
where v.VstReceipt<>'I'  AND  Isnull(rt.samplestatus,'D')  like  @statusflag
and V.vstdate>=@Vstdate and v.vstdate<@Vstdate
and v.Userid=@UserID and 
v.RegstrationCentrecode=@CentresCode
And Convert(varchar(5),C.CatCode) Like @CatCode 
order by v.vstdestination desc,v.vstdate desc
end
else            
begin            
SELECT DISTINCT top 100 V.VstCode,v.vstdestination as vstdestination,    
V.VstDate, V.VstPatCode,V.RefNo as IPOPNO, P.PatTitle ,              
P.PatName + '[' + P.PatSex + '\' + V.VstXRefNo +']' as PatName ,              
V.VstXRefNo as Age , P.PatSex  ,v.IsVIPPatient            
FROM Visit      v         
INNER JOIN Patient   p ON V.VstPatCode = P.PatCode              
INNER JOIN ResultTest rt  ON V.VstCode = Rt.RtJobCode              
INNER JOIN Category c ON Rt.RtCat = C.Category              
INNER JOIN UserCategory  uc ON C.CatCode=Uc.CatCode              
WHERE   
isnull(Rt.SampleStatus,'D') like @StatusFlag              
--And Visit.RefNo Like @IPOPNo              
--And visit.vstDestination Like @ReqNo    
And (v.vstDestination Like @ReqNo  OR  v.REFNO Like @ReqNo)   
And V.VstDate >= @Vstdate -2         
--And Visit.VstDate >= case when datediff(d,@Vstdate,getdate()) > 1 then @Vstdate else getdate()-1 end  
--And visit.vstdate <=@Todt            
---And isnull(Visit.IPOP,'O') like @IPOP              
--And ResultTest.LabNo <> 0              
And v.VstReceipt <> 'I' And isnull(C.BarcodeCopy,0) > 0              
And Uc.UserId=@UserID              
And Convert(varchar(5),C.CatCode) Like @CatCode    
And V.RegstrationCentreCode = @CentresCode            
--And (isnull(Visit.RegstrationCentreCode,'') like @CentresCode              
--OR isnull(ResultTest.ProcessingCenCode,'') like @ProcessCentresCode)         
--And Resulttest.rtintest <> '0'            
Order by V.VstDate desc, vstdestination desc  

end
End Try
Begin Catch
DECLARE @MESSAGE AS VARCHAR(500)= CONCAT('ERROR_MESSAGE - ',ERROR_MESSAGE(),'ERROR_LINE - ',ERROR_LINE(),'ERROR_NUMBER - ',ERROR_NUMBER(),'ERROR_SEVERITY - ',ERROR_SEVERITY(),'ERROR_PROCEDURE - ',ERROR_PROCEDURE())  
RAISERROR(@MESSAGE,16,1);
End Catch

End




--Select * from Patient
--Select * from Visit
--Select * from Resulttest
--Select * from Usercategory
--Select * from Category
















GO

-- %% [markdown]
-- # [dbo].[Sp_UpdateOSLab]

-- %%
/****** Object:  StoredProcedure [dbo].[Sp_UpdateOSLab]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[Sp_UpdateOSLab]
(
@pJsonData nvarchar(max),@pRid int output,@pResult varchar(250) output
)
as
Begin
Set NoCount off;
Declare @IsJson int,@OSLabName varchar(100),@OSContactPerson Varchar(250),@OSAddress varchar(255),@OSPhone1 varchar(250),@OSPhone2 varchar(250),
@OSFax Varchar(20),
@OSEmailID varchar(30),@Valid varchar(1),@IsReffered Varchar(1)

BEGIN TRY
SET @pResult = ''
Set @IsJson= (Select ISJSON(@pJsonData))

if @IsJson=1
Begin

Select * into #OSLabMaster from openjson(@pJsonData) with
(
OSLabName varchar(100),OSContactPerson Varchar(250),OSAddress varchar(255),OSPhone1 varchar(250),OSPhone2 varchar(250),OSFax Varchar(20),
OSEmailID varchar(30),Valid varchar(1),IsReffered Varchar(1)
)
 
Set  @OSLabName=(Select OSLabName from  #OSLabMaster);
Set  @OSContactPerson=(Select OSContactPerson from  #OSLabMaster);
Set  @OSAddress=(Select OSAddress from  #OSLabMaster);
Set  @OSPhone1=(Select OSPhone1 from  #OSLabMaster);
Set  @OSPhone2=(Select OSPhone2 from  #OSLabMaster);
Set  @OSFax=(Select OSFax from  #OSLabMaster);
Set  @OSEmailID=(Select OSEmailID from  #OSLabMaster);
Set  @Valid=(Select Valid from  #OSLabMaster);
Set  @IsReffered=(Select IsReffered from  #OSLabMaster);


If Exists(Select * from OSLABMASTER where OSLabName=@OSLabName)
Begin
      Update OSLABMASTER
	  Set OSLabName=@OSLabName,
	  OSContactPerson=@OSContactPerson,
	  OSAddress=@OSAddress,
	  OSPhone1=@OSPhone1,
	  OSPhone2=@OSPhone2,
	  OSFax=@OSFax,
	  OSEmailID=@OSEmailID,
	  Valid=@Valid,
	  IsReffered=@IsReffered
        SET @pResult =  'LabName Details Updated Sucessfully';          
		SET @pRid=-2
End

else
Begin
              SET @pResult =  'Lab Name does not exists';         
			  SET @pRid=-1 
			  drop table #OSLabMaster
End
End

else
BEGIN
		SET @pResult =  'Error in JSON file.';          
		SET @pRid=0 
END
END TRY

BEGIN CATCH
    DECLARE @MESSAGE AS VARCHAR(500)= CONCAT('ERROR_MESSAGE - ',ERROR_MESSAGE(),'ERROR_LINE - ',ERROR_LINE(),'ERROR_NUMBER - ',ERROR_NUMBER(),'ERROR_SEVERITY - ',ERROR_SEVERITY(),'ERROR_PROCEDURE - ',ERROR_PROCEDURE())  
    RAISERROR(@MESSAGE,16,1);
END CATCH 
END
GO

-- %% [markdown]
-- # [dbo].[sp_UpdateParam]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_UpdateParam]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Proc [dbo].[sp_UpdateParam]
as
Begin
Set NoCount Off;
Select * from Param
End
GO

-- %% [markdown]
-- # [dbo].[Sp_UpdateReasons]

-- %%
/****** Object:  StoredProcedure [dbo].[Sp_UpdateReasons]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Proc [dbo].[Sp_UpdateReasons]
(
@pJsonData nvarchar(max),@pRid int output,@pResult varchar(250) output
)
as
Begin
Set NoCount off;
Declare @Reason nvarchar(255),@ReasonFlag nvarchar(2),
@IsJson int;

BEGIN TRY
SET @pResult = ''
Set @IsJson= (Select ISJSON(@pJsonData))

if @IsJson=1
Begin

Select * into #Reason from openjson(@pJsonData) with
(
Reason nvarchar(255),ReasonFlag nvarchar(2)
)
 
Set  @Reason=(Select Reason from  #Reason);
Set  @ReasonFlag=(Select ReasonFlag from  #Reason);


If Exists(Select * from Reason where Reason=@Reason)
Begin
      Update Reason
	  Set  Reason=@Reason,
	      ReasonFlag=@ReasonFlag
	   where Reason=@Reason
        SET @pResult =  'Reasons Updated';          
		SET @pRid=-2
End

else
Begin
              SET @pResult =  'Reasons not updated';         
			  SET @pRid=-1 
			  drop table #Reason
End
End

else
BEGIN
		SET @pResult =  'Error in JSON file.';          
		SET @pRid=0 
END
END TRY

BEGIN CATCH
    DECLARE @MESSAGE AS VARCHAR(500)= CONCAT('ERROR_MESSAGE - ',ERROR_MESSAGE(),'ERROR_LINE - ',ERROR_LINE(),'ERROR_NUMBER - ',ERROR_NUMBER(),'ERROR_SEVERITY - ',ERROR_SEVERITY(),'ERROR_PROCEDURE - ',ERROR_PROCEDURE())  
    RAISERROR(@MESSAGE,16,1);
END CATCH 
END
GO

-- %% [markdown]
-- # [dbo].[sp_UpdateTest]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_UpdateTest]    Script Date: 07/03/2025 8:53:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[sp_UpdateTest]
(
@pJsonData varchar(max),@pRid int output,@pResult varchar(250) output
)
as
BEGIN
Begin Try
SET NOCOUNT OFF;
Declare @IsJson int,@TestName varchar(255),@TestPrintAs nvarchar(255),@TestMethod nvarchar(100),@TestRate Money,  
@TestCategory Varchar(100),@TestOrder int,@TestSuppressNamePrint int,@TestKeepTogether Varchar(1),  
@TestPageSize int,@TestFooter Varchar(500),@TestCutCategory Varchar(1),@Cost Money,@TestOutSide varchar(1),  
@hmscode varchar(250),@SENDSMS varchar(1),@ViewReport Varchar(1),@SampleType Varchar(30),@testdays int,  
@TestOSLabCode int,@Testcount int,@cptcode varchar(250),@vcencode int,@samplevol varchar(50),  
@accrediation varchar(50),@autoauth varchar(1),@TAT int,@testalias varchar(250),@calccptcode varchar(255),  
@microspecialcpt varchar(255),@histospecialcpt varchar(250),@WEBTESTCODE varchar(50),@Micro_ESBLCPT varchar(50),  
@Micro_colonyCPT varchar(250),@testhmscode varchar(10),@autocomplete varchar(1),@vattestcatcode int,@testschedule varchar(50),  
@TestReorder int,@SampleCollectionMethod varchar(100),@doneby varchar(250),@adactivity varchar(250),@compname varchar(250)  

SET @pResult = ''     
Set @IsJson= (Select ISJSON(@pJsonData))   
if(@IsJson=1)    
Begin    
Select * into #Test from openjson(@pJsonData) with     
(    
TestName nVarchar(255),TestPrintAs nvarchar(255),TestMethod nvarchar(255),TestRate Money,  
TestCategory Varchar(100),TestOrder int,TestSuppressNamePrint int,TestKeepTogether Varchar(1),  
TestPageSize int,TestFooter Varchar(500),TestCutCategory Varchar(1),Cost Money,TestOutSide varchar(1),  
hmscode varchar(250),SENDSMS varchar(1),ViewReport Varchar(1),SampleType Varchar(30),testdays int,  
TestOSLabCode int,Testcount int,cptcode varchar(250),vcencode int,samplevol varchar(50),  
accrediation varchar(50),autoauth varchar(1),TAT int,testalias varchar(250),calccptcode varchar(255),  
microspecialcpt varchar(255),histospecialcpt varchar(250),WEBTESTCODE varchar(50),Micro_ESBLCPT varchar(50),  
Micro_colonyCPT varchar(250),testhmscode varchar(10),autocomplete varchar(1),vattestcatcode int,testschedule varchar(50),  
TestReorder int,SampleCollectionMethod varchar(100),doneby varchar(250),adactivity varchar(250),compname varchar(250)  
)   

Set @TestName=(Select Testname from #Test);
Set @TestPrintAs=(Select TestPrintAs from #Test);
Set @TestMethod=(Select TestMethod from #Test);
Set @TestRate=(Select TestRate from #Test);
Set @TestCategory=(Select TestCategory from #Test);
Set @TestSuppressNamePrint=(Select TestSuppressNamePrint from #Test);
Set @TestKeepTogether=(Select TestKeepTogether from #Test);
Set @TestPageSize=(Select TestPageSize from #Test);
Set @TestFooter=(Select TestFooter from #Test);
Set @TestCutCategory=(Select TestCutCategory from #Test);
Set @Cost=(Select Cost from #Test);
Set @TestOutSide=(Select TestOutSide from #Test);
Set @SENDSMS=(Select SENDSMS from #Test);
Set @ViewReport=(Select ViewReport from #Test);
Set @SampleType=(Select SampleType from #Test);
Set @testdays=(Select testdays from #Test);
Set @TestOSLabCode=(Select TestOSLabCode from #Test);
Set @Testcount=(Select Testcount from #Test);
Set @vcencode=(Select vcencode from #Test);
Set @samplevol=(Select samplevol from #Test);
Set @accrediation=(Select accrediation from #Test);
Set @TAT=(Select TAT from #Test);
Set @testalias=(Select testalias from #Test);
Set @calccptcode=(Select calccptcode from #Test);
Set @microspecialcpt=(Select microspecialcpt from #Test);
Set @histospecialcpt=(Select histospecialcpt from #Test);
Set @Micro_ESBLCPT=(Select Micro_ESBLCPT from #Test);
Set @testhmscode=(Select testhmscode from #Test);
Set @autocomplete=(Select autocomplete from #Test);
Set @vattestcatcode=(Select vattestcatcode from #Test);
Set @testschedule=(Select testschedule from #Test);
Set @TestReorder=(Select TestReorder from #Test);
Set @SampleCollectionMethod=(Select SampleCollectionMethod from #Test);
Set @doneby=(Select doneby from #Test);
Set @adactivity=(Select adactivity from #Test);
Set @compname=(Select compname from #Test);

If Exists(Select  * from Test where TestName=@TestName)
Begin
    Update Test Set 
TestName=@TestName,
TestPrintAs=@TestPrintAs,
TestMethod=@TestMethod,
TestRate=@TestRate,  
TestCategory=@TestCategory,
TestOrder=@TestOrder,
TestSuppressNamePrint=@TestSuppressNamePrint,
TestKeepTogether=@TestKeepTogether,  
TestPageSize=@TestPageSize,
TestFooter=@TestFooter,
TestCutCategory=@TestCutCategory,
Cost=@Cost,
TestOutSide=@TestOutSide,  
hmscode=@hmscode,
SENDSMS=@SENDSMS,
ViewReport=@ViewReport,
SampleType=@SampleType,
testdays=@testdays,  
TestOSLabCode=@TestOSLabCode,
Testcount=@Testcount,
cptcode=@cptcode,
vcencode=@vcencode,
samplevol=@samplevol,  
accrediation=@accrediation,
autoauth=@autoauth,
TAT=@TAT,
testalias=@testalias,
calccptcode=@calccptcode,  
microspecialcpt=@microspecialcpt,
histospecialcpt=@histospecialcpt,
WEBTESTCODE=@WEBTESTCODE,
Micro_ESBLCPT=@Micro_ESBLCPT,  
Micro_colonyCPT=@Micro_colonyCPT,
testhmscode=@testhmscode,
autocomplete=@autocomplete,
vattestcatcode=@vattestcatcode,
testschedule=@testschedule,  
TestReorder=@TestReorder,
SampleCollectionMethod=@SampleCollectionMethod,
doneby=@doneby,
adactivity=@adactivity,
compname=@compname
where TestName=@TestName

  SET @pResult =  'Test Updated Sucessfully';              
  SET @pRid=2  
      
End
else
Begin

     SET @pResult =  'TestName does not exist';              
     SET @pRid=-1  
end
end
else    
begin   
  SET @pResult =  'Error in JSON file.';              
  SET @pRid=0     
end 
End Try
BEGIN CATCH
DECLARE @MESSAGE AS VARCHAR(500)= CONCAT('ERROR_MESSAGE - ',ERROR_MESSAGE(),'ERROR_LINE - ',ERROR_LINE(),'ERROR_NUMBER - ',ERROR_NUMBER(),'ERROR_SEVERITY - ',ERROR_SEVERITY(),'ERROR_PROCEDURE - ',ERROR_PROCEDURE())  
RAISERROR(@MESSAGE,16,1);
END CATCH 
END
GO

-- %% [markdown]
-- # [Labcare_New]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Labcare_New] SET  READ_WRITE 
GO
